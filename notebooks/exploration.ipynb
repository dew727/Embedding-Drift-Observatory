# %% [markdown]
# # Embedding Drift Observatory — EDA & Prototyping
#
# Use this notebook for exploratory analysis and prototyping before integrating into the main pipeline.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '..')  # Add project root to path
